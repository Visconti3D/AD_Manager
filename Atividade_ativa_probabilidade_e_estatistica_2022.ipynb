# %% [markdown]
# <a href="https://colab.research.google.com/github/Visconti3D/AD_Manager/blob/main/Atividade_ativa_probabilidade_e_estatistica_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center>IESB EAD - Probabilidade e estatistica</h1>

# %% [markdown]
# # Caro aluno,
#
# Pontuação (0,25 Pontos)
# *	Quantas reclamações foram registradas em 2016, contidas nesta base?
# *	Qual região houve mais reclamação? E qual houve menos?
# *	Qual a quantidade de reclamações realizadas por homens? E por mulheres?
#
# Pontuação (0,25 Pontos)
# *	Em qual região os homens fizeram mais reclamações que as mulheres?
# *	Qual a faixa etária que realizou mais reclamações?
# *	Quais assuntos apresentaram mais reclamações em 2016?
# *	Analisando o nome fantasia, determine qual empresa recebeu mais reclamações em 2016.
# *	Qual empresa possui um maior percentual de resolução de reclamações?
#
#
#
# Pontuação (1 Ponto)
#
# *	Monte um gráfico mostrando a quantidade de reclamações por região, separando as mesmas por sexo.
# *	Elabore um gráfico de linhas com a quantidade de reclamações por mês. Este gráfico lembra alguma distribuição estatística?
# *	Elabore um gráfico boxplot mostrando a quantidade de reclamações por região.
#
# Pontuação (0,5 Pontos)
#
# *	É possível afirmar que existe correlação entre o número de reclamações E o número de habitantes por Estado? Elabore um gráfico de dispersão e calcule o índice de correlação destes dois fatores.
#
#
# Todo o trabalho deverá ser feito utilizando notebook Python. Pode ser utilizado a plataforma Google Colaboratory e todos os itens acima deverão ser demonstrados. NÃO SERÃO ACEITO APENAS AS RESPOSTAS AS PERGUNTAS. O aluno deverá apresentar todos os comandos utilizados para obter as informações solicitadas.
#
# O aluno deverá imprimir o notebook em formato PDF e submeter no campo atividade ativa, juntamente com o Notebook do projeto.
#
# Não serão corrigidos trabalhos com formato diferente de PDF como .ZIP,tar, ou imagens.
#
# #Material de Apoio para uso do Pandas
#
# https://www.kaggle.com/joaoavf/introducao-a-analise-de-dados-python-e-pandas

# %%
#Iniciando a utilização da biblioteca pandas
import pandas as pd
import seaborn as sns

# %%
#importando os dados para o google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d27e5bf6-316c-4de6-96a4-d57932dffde0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d27e5bf6-316c-4de6-96a4-d57932dffde0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e0d75c7b0136> in <module>()
#       1 #importando os dados para o google colab
#       2 from google.colab import files
# ----> 3 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 63           input_id=input_id, output_id=output_id))
#      64   files = _collections.defaultdict(_six.binary_type)
#      65   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
dfs = pd.read_csv("reclamacoes-fundamentadas-sindec-2016.csv")

# %%
orig_url='https://drive.google.com/file/d/1pkOP40FvztNt0pnWgKMG5iTXzRt4TW_N/view?usp=sharing'

# %%
#Os dados podem ser importados diretamente da internet, sem a necessidade de ser armazenada no computador local utilizando os comandos listados abaixo
#Fazendo o upload via google Drive. Para isso será necessário o uso de uma função que foi desenvolvida abaixo

import requests
from io import StringIO

orig_url='https://drive.google.com/file/d/1pkOP40FvztNt0pnWgKMG5iTXzRt4TW_N/view?usp=sharing'


file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
dfs = pd.read_csv(csv_raw)
print(dfs.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ee40256814ee> in <module>()
#      12 url = requests.get(dwn_url).text
#      13 csv_raw = StringIO(url)
# ---> 14 dfs = pd.read_csv(csv_raw)
#      15 print(dfs.head())
#
# NameError: name 'pd' is not defined

# %%
#Visualizando as primeiras cinco linhas 
dfs.head()
# Out:
#    ï»¿AnoCalendario  ... CEPConsumidor
# 0              2016  ...    52061540.0
# 1              2016  ...    51010140.0
# 2              2016  ...    53060600.0
# 3              2016  ...    53090220.0
# 4              2016  ...    53437100.0
#
# [5 rows x 23 columns]

# %%
#Visualizando as ultimas cinco linhas 
dfs.tail()
# Out:
#         ï»¿AnoCalendario  ... CEPConsumidor
# 203481              2016  ...     4763310.0
# 203482              2016  ...     4846010.0
# 203483              2016  ...     5731090.0
# 203484              2016  ...     4438250.0
# 203485              2016  ...     4470261.0
#
# [5 rows x 23 columns]

# %%
#Visualizando a amostra dos dados aleatória com 5 linhas
dfs.sample(5)
# Out:
#         ï»¿AnoCalendario  ... CEPConsumidor
# 38678               2016  ...    41190140.0
# 65750               2016  ...    57062590.0
# 74215               2016  ...    54800000.0
# 191585              2016  ...    76820749.0
# 34821               2016  ...           NaN
#
# [5 rows x 23 columns]

# %%
#Visualizando as linhas 10 a 20 do dataset
dfs[10:21]
# Out:
#     ï»¿AnoCalendario  ... CEPConsumidor
# 10              2016  ...    50860130.0
# 11              2016  ...    51010680.0
# 12              2016  ...    89580000.0
# 13              2016  ...    89240000.0
# 14              2016  ...    81830280.0
# 15              2016  ...    82120340.0
# 16              2016  ...    75025070.0
# 17              2016  ...    83321090.0
# 18              2016  ...    83404160.0
# 19              2016  ...           NaN
# 20              2016  ...    75250000.0
#
# [11 rows x 23 columns]

# %%
#Visualizando uma coluna especifica do Dataset. Repare que foram utilizados dois pares de Colchetes
dfs[['Regiao','UF','SexoConsumidor']]
# Out:
#           Regiao  UF SexoConsumidor
# 0       Nordeste  PE              M
# 1       Nordeste  PE              F
# 2       Nordeste  PE              F
# 3       Nordeste  PE              M
# 4       Nordeste  PE              F
# ...          ...  ..            ...
# 203481   Sudeste  SP              M
# 203482   Sudeste  SP              M
# 203483   Sudeste  SP              F
# 203484   Sudeste  SP              F
# 203485   Sudeste  SP              M
#
# [203486 rows x 3 columns]

# %%
#Um Dataset temporário pode ser montado com os dados das colunas
dfs_temp = dfs[['Regiao','SexoConsumidor']]

# %%
#Qual a quantidade de reclamações realizadas por mulheres?
dfs_temp['SexoConsumidor'].value_counts()
# Out:
# F    107229
# M     94446
# N      1809
# Name: SexoConsumidor, dtype: int64

# %% [markdown]
# #Exercicio
# * Monte uma tabela mostrando a quantidade de reclamações por região E Sexo. Qual região houve mais reclamações por parte das mulheres?
# * Monte um gráfico mostrando a quantidade de reclamações por região, separando as mesmas por sexo.

# %%
#Monte um gráfico mostrando a quantidade de reclamações por região, separando as mesmas por sexo

sns.countplot(x='Regiao', hue='SexoConsumidor',data=dfs_temp)

# %%
#Fazendo analise estatistica do dataset
dfs.describe()
# Out:
#        ï»¿AnoCalendario  CodigoRegiao  ...  CodigoProblema  CEPConsumidor
# count          203486.0  203486.00000  ...   203476.000000   1.894000e+05
# mean             2016.0       2.89616  ...      120.828766   5.160439e+07
# std                 0.0       1.17781  ...       58.999782   2.684505e+07
# min              2016.0       1.00000  ...        1.000000   0.000000e+00
# 25%              2016.0       2.00000  ...      105.000000   3.101010e+07
# 50%              2016.0       3.00000  ...      107.000000   5.600000e+07
# 75%              2016.0       4.00000  ...      136.000000   7.727000e+07
# max              2016.0       5.00000  ...      262.000000   9.969800e+07
#
# [8 rows x 9 columns]

# %%
#Verificando quantas linhas e colunas possuem o dataset
dfs.shape
# Out:
# (203486, 23)

# %%
#Qual o nome de todas as colunas do dataset?
dfs.keys()
# Out:
# Index(['ï»¿AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
#Qual a probabilidade de uma linha escolhida ao acaso no dataset ser de um consumidor que mora no nordeste?

# %%
#Passo 1 - descobrir quantas linhas existem no dataset referente ao Nordeste
dfs["Regiao"].value_counts()
# Out:
# Nordeste        66411
# Sudeste         62974
# Centro-oeste    28786
# Sul             26113
# Norte           19202
# Name: Regiao, dtype: int64

# %%
#Passo 2 - Descobrir quantas linhas existem no dataset
dfs.shape

# %%
#A probabilidade de uma linha escolhida ao acaso ser de um consumidor que mora na regiao Nordeste
prob = (66411 / 203486) * 100
print(prob)
# Out:
# 32.63664330715626

# %%
#ATENÇÃO - A partir de agora é a sua vez, continue respondendo os itens solicitados no exercicio.
